# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
from asyncevo import load

# %%
output = load("test.asyncga")

# %%
x = [i for i, step in enumerate(output['history']) for j in step]
y = [v for step in output['history'] for v in step]

# %%
plt.scatter(x, y, alpha=0.5, color='black', s=5)
plt.yscale('log')

# %%
from statistics import mean

# %%
my = [mean(step) for step in output['history']]
by = [max(step) for step in output['history']]

# %%
plt.plot(my)
plt.plot(by)

# %%
plt.plot(my)
plt.plot(by)

# %%
from asyncevo import Member

# %%
m = Member(output['initial_state'],
             output['table_seed'],
             output['table_size'],
             output['max_table_step'])

# %%
m.appropriate_lineage(output['population'][0]['lineage'])

# %%
print(m.parameters)
# Out:
# [ 0.73790866 -0.62632966 -0.00436214 -0.53305537  0.00920079 -0.32565182
#   0.3064322  -0.03960694]
